# %%
! pip install 'h5py==2.10.0' --force-reinstall
# Out:
# Collecting h5py==2.10.0
#   Using cached h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
# Collecting numpy>=1.7
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, numpy, h5py
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed h5py-2.10.0 numpy-1.21.6 six-1.16.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DATAPATH = "/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/"
RESULTPATH = "/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/results/"

# %%
import pandas as pd
import os
import numpy as np
#from gensim.models import Word2Vec, FastText
#import glove
#from glove import Corpus

import collections
import gc 

import keras
from keras import backend as K
from keras import regularizers
from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Dropout, Input, concatenate, merge, Activation, concatenate, LSTM, GRU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, BatchNormalization, GRU, Convolution1D, LSTM
from keras.layers import UpSampling1D, MaxPooling1D, GlobalMaxPooling1D, GlobalAveragePooling1D,MaxPool1D, merge

#from keras.optimizers import Adam

from keras.callbacks import EarlyStopping, ModelCheckpoint, History, ReduceLROnPlateau
from keras.utils import np_utils
#from keras.backend.tensorflow_backend import set_session, clear_session, get_session
from keras.backend import set_session, clear_session, get_session
import tensorflow as tf


from sklearn.utils import class_weight
from sklearn.metrics import average_precision_score, roc_auc_score, accuracy_score, f1_score

import warnings
warnings.filterwarnings('ignore')

# %%
lvl2_train =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/lvl2_imputer_train.pkl")
lvl2_dev =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/lvl2_imputer_dev.pkl")
lvl2_test =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/lvl2_imputer_test.pkl")

Ys =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/Ys.pkl")
Ys_train =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/Ys_train.pkl")
Ys_dev =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/Ys_dev.pkl")
Ys_test =  pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/Ys_test.pkl")

# %%
all_train_ids = set()
for i in Ys_train.itertuples():
    all_train_ids.add( i.Index[0] )
    
all_dev_ids = set()
for i in Ys_dev.itertuples():
    all_dev_ids.add( i.Index[0] )
    
all_test_ids = set()
for i in Ys_test.itertuples():
    all_test_ids.add( i.Index[0] )

# %%
type_of_ner = "new"

x_train_lstm = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_x_train.pkl")
x_dev_lstm = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_x_dev.pkl")
x_test_lstm = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_x_test.pkl")


y_train = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_y_train.pkl")
y_dev = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_y_dev.pkl")
y_test = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_y_test.pkl")


#ner_word2vec = pd.read_pickle("data/"+type_of_ner+"_ner_word2vec_limited_dict.pkl")
#ner_fasttext = pd.read_pickle("data/"+type_of_ner+"_ner_fasttext_limited_dict.pkl")
#ner_concat = pd.read_pickle("data/"+type_of_ner+"_ner_combined_limited_dict.pkl")

ner_word2vec = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_ner4_word2vec_limited_dict.pkl")
ner_fasttext = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_ner4_fasttext_limited_dict.pkl")
ner_concat = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/data/new_ner4_combined_limited_dict.pkl")

new_keys = set(ner_word2vec.keys())
train_ids = sorted(all_train_ids.intersection(new_keys))
dev_ids = sorted(all_dev_ids.intersection(new_keys))
test_ids = sorted(all_test_ids.intersection(new_keys))

#train_ids = pd.read_pickle("data/"+type_of_ner+"_train_ids.pkl")
#dev_ids = pd.read_pickle("data/"+type_of_ner+"_dev_ids.pkl")
#test_ids = pd.read_pickle("data/"+type_of_ner+"_test_ids.pkl")

# %%
def create_dataset(dict_of_ner):
    temp_data = []
    for k, v in sorted(dict_of_ner.items()):
        temp = []
        for embed in v:
            temp.append(embed)
        #temp_data.append(np.mean(temp, axis = 0))
        temp_data.append(temp) 
    return np.asarray(temp_data)

def make_prediction_cnn(model, test_data):
    probs = model.predict(test_data)
    y_pred = [1 if i>=0.5 else 0 for i in probs]
    return probs, y_pred

def save_scores_cnn(predictions, probs, ground_truth, 
                          
                          embed_name, problem_type, iteration, hidden_unit_size,
                          
                          sequence_name, type_of_ner):
    
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    result_dict = {}    
    result_dict['auc'] = auc
    result_dict['auprc'] = auprc
    result_dict['acc'] = acc
    result_dict['F1'] = F1

    result_path = "/content/drive/MyDrive/Colab Notebooks/ConvolutionMedicalNer-master/results/cnn/"
    file_name = str(sequence_name)+"-"+str(hidden_unit_size)+"-"+embed_name
    file_name = file_name +"-"+problem_type+"-"+str(iteration)+"-"+type_of_ner+"-cnn-.p"
    pd.to_pickle(result_dict, os.path.join(result_path, file_name))

    print(auc, auprc, acc, F1)
    
def print_scores_cnn(predictions, probs, ground_truth, model_name, problem_type, iteration, hidden_unit_size):
    auc = roc_auc_score(ground_truth, probs)
    auprc = average_precision_score(ground_truth, probs)
    acc   = accuracy_score(ground_truth, predictions)
    F1    = f1_score(ground_truth, predictions)
    
    print ("AUC: ", auc, "AUPRC: ", auprc, "F1: ", F1)
    
def get_subvector_data(size, embed_name, data):
    if embed_name == "concat":
        vector_size = 200
    else:
        vector_size = 100
    
    vector_size = 100
    x_data = {}
    for k, v in data.items():
        number_of_additional_vector = len(v) - size
        vector = []
        for i in v:
            vector.append(i)
        if number_of_additional_vector < 0: 
            number_of_additional_vector = np.abs(number_of_additional_vector)

            temp = vector[:size]
            for i in range(0, number_of_additional_vector):
                temp.append(np.zeros(vector_size))
            x_data[k] = np.asarray(temp)
        else:
            x_data[k] = np.asarray(vector[:size])

    return x_data


def proposedmodel(layer_name, number_of_unit, embedding_name, ner_limit, num_filter):
    if embedding_name == "concat":
        input_dimension = 200
    else:
        input_dimension = 100

    input_dimension = 100
    sequence_input = Input(shape=(24,104))

    input_img = Input(shape=(ner_limit, input_dimension), name = "cnn_input")

    convs = []
    filter_sizes = [2,3,4]



    text_conv1d = Conv1D(filters=num_filter, kernel_size=3, 
                 padding = 'valid', strides = 1, dilation_rate=1, activation='relu', 
                         kernel_initializer=tf.keras.initializers.glorot_normal() )(input_img)
    
    text_conv1d = Conv1D(filters=num_filter*2, kernel_size=3, 
                 padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                        kernel_initializer=tf.keras.initializers.glorot_normal())(text_conv1d)   
    
    text_conv1d = Conv1D(filters=num_filter*3, kernel_size=3, 
                 padding = 'valid', strides = 1, dilation_rate=1, activation='relu',
                        kernel_initializer=tf.keras.initializers.glorot_normal())(text_conv1d)   

    
    #concat_conv = keras.layers.Concatenate()([text_conv1d, text_conv1d_2, text_conv1d_3])
    text_embeddings = GlobalMaxPooling1D()(text_conv1d)
    #text_embeddings = Dense(128, activation="relu")(text_embeddings)
    
    if layer_name == "GRU":
        x = GRU(number_of_unit)(sequence_input)
    elif layer_name == "LSTM":
        x = LSTM(number_of_unit)(sequence_input)

    #concatenated = keras.layers.Concatenate()([x, text_embeddings])
    #concatenated = merge([x, text_embeddings], mode='concat', concat_axis=1)
    #concatenated = concatenate([x, text_embeddings])
    concatenated = keras.layers.Concatenate(axis=1)([x, text_embeddings])

    concatenated = Dense(512, activation='relu')(concatenated)
    concatenated = Dropout(0.2)(concatenated)
    #concatenated = Dense(256, activation='relu')(concatenated)
    #concatenated = Dense(512, activation='relu')(concatenated)
    
    #concatenated = Dense(512, activation='relu')(concatenated)
    #logits_regularizer = tf.contrib.layers.l2_regularizer(scale=0.01)
    logits_regularizer = tf.keras.regularizers.L2(0.01)
    preds = Dense(1, activation='sigmoid',use_bias=False,
                         kernel_initializer=tf.keras.initializers.glorot_normal(), 
                  kernel_regularizer=logits_regularizer)(concatenated)
    
    
    #opt = Adam(lr=1e-4, decay = 0.01)
    
    #opt = Adam(lr=1e-3, decay = 0.01)
    
    #opt = Adam(lr=0.001)

    model = Model(inputs=[sequence_input, input_img], outputs=preds)
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['acc'])
    
    return model

# %%
#print(tf.__version__)
#x_train_lstm = tf.convert_to_tensor(x_train_lstm, dtype=tf.float32)
#x_dev_lstm = tf.convert_to_tensor(x_dev_lstm, dtype=tf.float32)
#x_test_lstm = tf.convert_to_tensor(x_test_lstm, dtype=tf.float32)

#y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
#y_dev = tf.convert_to_tensor(y_dev, dtype=tf.float32)
#y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)

embedding_types = ['word2vec', 'fasttext', 'concat']
embedding_dict = [ner_word2vec, ner_fasttext, ner_concat]
#embedding_dict = [ner_word2vec, ner_fasttext]
#embedding_types = ['word2vec', 'fasttext']
#embedding_types = ['concat']
#embedding_dict = [ner_concat]

target_problems = ['mort_hosp', 'mort_icu', 'los_3', 'los_7']
#target_problems = [1, 2, 3, 4]

num_epoch = 100
model_patience = 5
monitor_criteria = 'val_loss'
#monitor_criteria = 'val_acc'
batch_size = 64

filter_number = 32
ner_representation_limit = 64
activation_func = "relu"

sequence_model = "GRU"
sequence_hidden_unit = 256

maxiter = 11
for embed_dict, embed_name in zip(embedding_dict, embedding_types):    
    print ("Embedding: ", embed_name)
    print("=============================")
    
    temp_train_ner = dict((k, embed_dict[k]) for k in train_ids)
    tem_dev_ner = dict((k, embed_dict[k]) for k in dev_ids)
    temp_test_ner = dict((k, embed_dict[k]) for k in test_ids)

    x_train_dict = {}
    x_dev_dict = {}
    x_test_dict = {}

    x_train_dict = get_subvector_data(ner_representation_limit, embed_name, temp_train_ner)
    x_dev_dict = get_subvector_data(ner_representation_limit, embed_name, tem_dev_ner)
    x_test_dict = get_subvector_data(ner_representation_limit, embed_name, temp_test_ner)

    x_train_dict_sorted = collections.OrderedDict(sorted(x_train_dict.items()))
    x_dev_dict_sorted = collections.OrderedDict(sorted(x_dev_dict.items()))
    x_test_dict_sorted = collections.OrderedDict(sorted(x_test_dict.items()))

    x_train_ner = np.asarray(list(x_train_dict_sorted.values()))
    x_dev_ner = np.asarray(list(x_dev_dict_sorted.values()))
    x_test_ner = np.asarray(list(x_test_dict_sorted.values()))
     
    for iteration in range(1,maxiter):
        print ("Iteration number: ", iteration)
    
        for each_problem in target_problems:
            print ("Problem type: ", each_problem)
            print ("__________________")  
            
            
            early_stopping_monitor = EarlyStopping(monitor=monitor_criteria, patience=model_patience)
            
            best_model_name = str(ner_representation_limit)+"-basiccnn1d-"+str(embed_name)+"-"+str(each_problem)+"-"+"best_model.hdf5"
            
            checkpoint = ModelCheckpoint(best_model_name, monitor=monitor_criteria, verbose=1,
                save_best_only=True, mode='min')
            
            reduce_lr = ReduceLROnPlateau(monitor=monitor_criteria, factor=0.2,
                              patience=2, min_lr=0.00001, epsilon=1e-4, mode='min')
            

            #callbacks = [early_stopping_monitor, checkpoint, reduce_lr]
            callbacks = [early_stopping_monitor, checkpoint]
            
            #model = textCNN(sequence_model, sequence_hidden_unit, embed_name, ner_representation_limit)
            model = proposedmodel(sequence_model, sequence_hidden_unit, embed_name, ner_representation_limit,filter_number)
            model.fit([x_train_lstm, x_train_ner], y_train[each_problem], epochs=num_epoch, verbose=1, 
                      validation_data=([x_dev_lstm, x_dev_ner], y_dev[each_problem]), callbacks=callbacks, batch_size=batch_size)
            
            
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            print_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration, sequence_hidden_unit)
            
            model.load_weights(best_model_name)
                      
            probs, predictions = make_prediction_cnn(model, [x_test_lstm, x_test_ner])
            save_scores_cnn(predictions, probs, y_test[each_problem], embed_name, each_problem, iteration,
                            sequence_hidden_unit, sequence_model, type_of_ner)
            del model
            clear_session()
            gc.collect()
# Out:
# Embedding:  word2vec
# =============================
# Iteration number:  1
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2826 - acc: 0.9030
# Epoch 1: val_loss improved from inf to 0.24516, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 20s 72ms/step - loss: 0.2826 - acc: 0.9030 - val_loss: 0.2452 - val_acc: 0.9127
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2368 - acc: 0.9163
# Epoch 2: val_loss improved from 0.24516 to 0.24351, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 16s 69ms/step - loss: 0.2368 - acc: 0.9163 - val_loss: 0.2435 - val_acc: 0.9159
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2197 - acc: 0.9220
# Epoch 3: val_loss improved from 0.24351 to 0.24155, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 17s 73ms/step - loss: 0.2197 - acc: 0.9220 - val_loss: 0.2415 - val_acc: 0.9150
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1982 - acc: 0.9282
# Epoch 4: val_loss did not improve from 0.24155
# 238/238 [==============================] - 17s 72ms/step - loss: 0.1982 - acc: 0.9282 - val_loss: 0.2431 - val_acc: 0.9154
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1759 - acc: 0.9326
# Epoch 5: val_loss did not improve from 0.24155
# 238/238 [==============================] - 18s 76ms/step - loss: 0.1759 - acc: 0.9326 - val_loss: 0.3021 - val_acc: 0.9108
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1486 - acc: 0.9434
# Epoch 6: val_loss did not improve from 0.24155
# 238/238 [==============================] - 18s 74ms/step - loss: 0.1486 - acc: 0.9434 - val_loss: 0.2709 - val_acc: 0.9039
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1169 - acc: 0.9562
# Epoch 7: val_loss did not improve from 0.24155
# 238/238 [==============================] - 17s 71ms/step - loss: 0.1169 - acc: 0.9562 - val_loss: 0.3017 - val_acc: 0.8970
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0872 - acc: 0.9696
# Epoch 8: val_loss did not improve from 0.24155
# 238/238 [==============================] - 18s 75ms/step - loss: 0.0872 - acc: 0.9696 - val_loss: 0.3423 - val_acc: 0.9043
# AUC:  0.8509912767644726 AUPRC:  0.5194621360875117 F1:  0.4441489361702128
# 0.8745456648162835 0.583650914073297 0.9135234590616376 0.4835164835164836
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2247 - acc: 0.9313
# Epoch 1: val_loss improved from inf to 0.18227, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 20s 75ms/step - loss: 0.2247 - acc: 0.9313 - val_loss: 0.1823 - val_acc: 0.9469
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1745 - acc: 0.9428
# Epoch 2: val_loss improved from 0.18227 to 0.17163, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 17s 72ms/step - loss: 0.1745 - acc: 0.9428 - val_loss: 0.1716 - val_acc: 0.9436
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1571 - acc: 0.9456
# Epoch 3: val_loss improved from 0.17163 to 0.17098, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 17s 71ms/step - loss: 0.1571 - acc: 0.9456 - val_loss: 0.1710 - val_acc: 0.9464
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1406 - acc: 0.9498
# Epoch 4: val_loss improved from 0.17098 to 0.17019, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 18s 74ms/step - loss: 0.1406 - acc: 0.9498 - val_loss: 0.1702 - val_acc: 0.9482
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1224 - acc: 0.9551
# Epoch 5: val_loss did not improve from 0.17019
# 238/238 [==============================] - 17s 73ms/step - loss: 0.1224 - acc: 0.9551 - val_loss: 0.1842 - val_acc: 0.9409
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0978 - acc: 0.9643
# Epoch 6: val_loss did not improve from 0.17019
# 238/238 [==============================] - 19s 82ms/step - loss: 0.0978 - acc: 0.9643 - val_loss: 0.2124 - val_acc: 0.9302
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0743 - acc: 0.9716
# Epoch 7: val_loss did not improve from 0.17019
# 238/238 [==============================] - 20s 83ms/step - loss: 0.0743 - acc: 0.9716 - val_loss: 0.2416 - val_acc: 0.9321
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0490 - acc: 0.9846
# Epoch 8: val_loss did not improve from 0.17019
# 238/238 [==============================] - 20s 83ms/step - loss: 0.0490 - acc: 0.9846 - val_loss: 0.3163 - val_acc: 0.9385
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0370 - acc: 0.9878
# Epoch 9: val_loss did not improve from 0.17019
# 238/238 [==============================] - 20s 82ms/step - loss: 0.0370 - acc: 0.9878 - val_loss: 0.3442 - val_acc: 0.9330
# AUC:  0.8518836712080777 AUPRC:  0.48250210325000725 F1:  0.4652908067542214
# 0.877091624139707 0.5112567493984472 0.9397424103035878 0.44017094017094016
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6650 - acc: 0.6292
# Epoch 1: val_loss improved from inf to 0.61691, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 22s 81ms/step - loss: 0.6650 - acc: 0.6292 - val_loss: 0.6169 - val_acc: 0.6742
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6254 - acc: 0.6623
# Epoch 2: val_loss did not improve from 0.61691
# 238/238 [==============================] - 19s 80ms/step - loss: 0.6254 - acc: 0.6623 - val_loss: 0.6268 - val_acc: 0.6511
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6091 - acc: 0.6788
# Epoch 3: val_loss improved from 0.61691 to 0.61373, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 79ms/step - loss: 0.6091 - acc: 0.6788 - val_loss: 0.6137 - val_acc: 0.6687
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5880 - acc: 0.6952
# Epoch 4: val_loss improved from 0.61373 to 0.61200, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5880 - acc: 0.6952 - val_loss: 0.6120 - val_acc: 0.6742
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5625 - acc: 0.7150
# Epoch 5: val_loss did not improve from 0.61200
# 238/238 [==============================] - 18s 75ms/step - loss: 0.5625 - acc: 0.7150 - val_loss: 0.6301 - val_acc: 0.6506
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5249 - acc: 0.7435
# Epoch 6: val_loss did not improve from 0.61200
# 238/238 [==============================] - 18s 76ms/step - loss: 0.5249 - acc: 0.7435 - val_loss: 0.6494 - val_acc: 0.6599
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4714 - acc: 0.7780
# Epoch 7: val_loss did not improve from 0.61200
# 238/238 [==============================] - 18s 77ms/step - loss: 0.4714 - acc: 0.7780 - val_loss: 0.7250 - val_acc: 0.6299
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4054 - acc: 0.8150
# Epoch 8: val_loss did not improve from 0.61200
# 238/238 [==============================] - 18s 77ms/step - loss: 0.4054 - acc: 0.8150 - val_loss: 0.7744 - val_acc: 0.6192
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.3227 - acc: 0.8606
# Epoch 9: val_loss did not improve from 0.61200
# 238/238 [==============================] - 18s 78ms/step - loss: 0.3227 - acc: 0.8606 - val_loss: 0.8883 - val_acc: 0.6308
# AUC:  0.654590341529524 AUPRC:  0.6039085221065266 F1:  0.5719280719280719
# 0.6979984289555576 0.6405074711977884 0.6554737810487581 0.5780281690140845
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2861 - acc: 0.9200
# Epoch 1: val_loss improved from inf to 0.25940, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 22s 81ms/step - loss: 0.2861 - acc: 0.9200 - val_loss: 0.2594 - val_acc: 0.9247
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2528 - acc: 0.9219
# Epoch 2: val_loss improved from 0.25940 to 0.25280, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2528 - acc: 0.9219 - val_loss: 0.2528 - val_acc: 0.9247
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2399 - acc: 0.9216
# Epoch 3: val_loss did not improve from 0.25280
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2399 - acc: 0.9216 - val_loss: 0.2576 - val_acc: 0.9238
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2281 - acc: 0.9236
# Epoch 4: val_loss did not improve from 0.25280
# 238/238 [==============================] - 18s 75ms/step - loss: 0.2281 - acc: 0.9236 - val_loss: 0.2578 - val_acc: 0.9247
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2068 - acc: 0.9254
# Epoch 5: val_loss did not improve from 0.25280
# 238/238 [==============================] - 18s 76ms/step - loss: 0.2068 - acc: 0.9254 - val_loss: 0.2731 - val_acc: 0.9224
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1828 - acc: 0.9323
# Epoch 6: val_loss did not improve from 0.25280
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1828 - acc: 0.9323 - val_loss: 0.2850 - val_acc: 0.9131
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1473 - acc: 0.9474
# Epoch 7: val_loss did not improve from 0.25280
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1473 - acc: 0.9474 - val_loss: 0.3183 - val_acc: 0.9053
# AUC:  0.6586776080250388 AUPRC:  0.16573801383535508 F1:  0.16184971098265896
# 0.7263248406926212 0.22121104326382035 0.9183532658693653 0.005602240896358543
# Iteration number:  2
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2883 - acc: 0.9028
# Epoch 1: val_loss improved from inf to 0.25131, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 22s 81ms/step - loss: 0.2883 - acc: 0.9028 - val_loss: 0.2513 - val_acc: 0.9140
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2395 - acc: 0.9148
# Epoch 2: val_loss improved from 0.25131 to 0.23800, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 19s 81ms/step - loss: 0.2395 - acc: 0.9148 - val_loss: 0.2380 - val_acc: 0.9127
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2173 - acc: 0.9215
# Epoch 3: val_loss improved from 0.23800 to 0.23751, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 18s 78ms/step - loss: 0.2173 - acc: 0.9215 - val_loss: 0.2375 - val_acc: 0.9145
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2013 - acc: 0.9264
# Epoch 4: val_loss did not improve from 0.23751
# 238/238 [==============================] - 18s 78ms/step - loss: 0.2013 - acc: 0.9264 - val_loss: 0.2427 - val_acc: 0.9104
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1780 - acc: 0.9322
# Epoch 5: val_loss did not improve from 0.23751
# 238/238 [==============================] - 18s 76ms/step - loss: 0.1780 - acc: 0.9322 - val_loss: 0.2711 - val_acc: 0.8914
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1520 - acc: 0.9421
# Epoch 6: val_loss did not improve from 0.23751
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1520 - acc: 0.9421 - val_loss: 0.2735 - val_acc: 0.9187
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1177 - acc: 0.9567
# Epoch 7: val_loss did not improve from 0.23751
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1177 - acc: 0.9567 - val_loss: 0.3466 - val_acc: 0.9127
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0920 - acc: 0.9662
# Epoch 8: val_loss did not improve from 0.23751
# 238/238 [==============================] - 19s 78ms/step - loss: 0.0920 - acc: 0.9662 - val_loss: 0.3625 - val_acc: 0.8979
# AUC:  0.8549817164507886 AUPRC:  0.5457915527025954 F1:  0.48856799037304455
# 0.8846429200810645 0.5807312818109396 0.9089236430542779 0.4816753926701571
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2222 - acc: 0.9311
# Epoch 1: val_loss improved from inf to 0.17785, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 21s 78ms/step - loss: 0.2222 - acc: 0.9311 - val_loss: 0.1779 - val_acc: 0.9409
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1747 - acc: 0.9420
# Epoch 2: val_loss improved from 0.17785 to 0.17620, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1747 - acc: 0.9420 - val_loss: 0.1762 - val_acc: 0.9436
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1581 - acc: 0.9455
# Epoch 3: val_loss improved from 0.17620 to 0.17129, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1581 - acc: 0.9455 - val_loss: 0.1713 - val_acc: 0.9409
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1390 - acc: 0.9512
# Epoch 4: val_loss improved from 0.17129 to 0.17038, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 18s 78ms/step - loss: 0.1390 - acc: 0.9512 - val_loss: 0.1704 - val_acc: 0.9409
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1216 - acc: 0.9558
# Epoch 5: val_loss did not improve from 0.17038
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1216 - acc: 0.9558 - val_loss: 0.1908 - val_acc: 0.9353
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1007 - acc: 0.9636
# Epoch 6: val_loss did not improve from 0.17038
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1007 - acc: 0.9636 - val_loss: 0.2047 - val_acc: 0.9409
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0741 - acc: 0.9724
# Epoch 7: val_loss did not improve from 0.17038
# 238/238 [==============================] - 18s 77ms/step - loss: 0.0741 - acc: 0.9724 - val_loss: 0.2202 - val_acc: 0.9404
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0555 - acc: 0.9811
# Epoch 8: val_loss did not improve from 0.17038
# 238/238 [==============================] - 18s 76ms/step - loss: 0.0555 - acc: 0.9811 - val_loss: 0.2768 - val_acc: 0.9085
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0304 - acc: 0.9907
# Epoch 9: val_loss did not improve from 0.17038
# 238/238 [==============================] - 18s 75ms/step - loss: 0.0304 - acc: 0.9907 - val_loss: 0.3677 - val_acc: 0.9399
# AUC:  0.8472973922000093 AUPRC:  0.46006585891829455 F1:  0.4121212121212121
# 0.8717008442967056 0.5060589836099769 0.9397424103035878 0.40990990990990994
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6700 - acc: 0.6232
# Epoch 1: val_loss improved from inf to 0.62669, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 23s 83ms/step - loss: 0.6700 - acc: 0.6232 - val_loss: 0.6267 - val_acc: 0.6738
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6263 - acc: 0.6639
# Epoch 2: val_loss improved from 0.62669 to 0.62556, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.6263 - acc: 0.6639 - val_loss: 0.6256 - val_acc: 0.6613
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6085 - acc: 0.6819
# Epoch 3: val_loss did not improve from 0.62556
# 238/238 [==============================] - 18s 77ms/step - loss: 0.6085 - acc: 0.6819 - val_loss: 0.6268 - val_acc: 0.6733
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5892 - acc: 0.6984
# Epoch 4: val_loss improved from 0.62556 to 0.61983, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.5892 - acc: 0.6984 - val_loss: 0.6198 - val_acc: 0.6604
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5604 - acc: 0.7165
# Epoch 5: val_loss did not improve from 0.61983
# 238/238 [==============================] - 18s 77ms/step - loss: 0.5604 - acc: 0.7165 - val_loss: 0.6203 - val_acc: 0.6761
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5280 - acc: 0.7430
# Epoch 6: val_loss did not improve from 0.61983
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5280 - acc: 0.7430 - val_loss: 0.6464 - val_acc: 0.6539
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4770 - acc: 0.7778
# Epoch 7: val_loss did not improve from 0.61983
# 238/238 [==============================] - 18s 77ms/step - loss: 0.4770 - acc: 0.7778 - val_loss: 0.7148 - val_acc: 0.6613
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4104 - acc: 0.8156
# Epoch 8: val_loss did not improve from 0.61983
# 238/238 [==============================] - 19s 78ms/step - loss: 0.4104 - acc: 0.8156 - val_loss: 0.7602 - val_acc: 0.6423
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.3264 - acc: 0.8623
# Epoch 9: val_loss did not improve from 0.61983
# 238/238 [==============================] - 19s 78ms/step - loss: 0.3264 - acc: 0.8623 - val_loss: 0.8862 - val_acc: 0.6174
# AUC:  0.6591513338771564 AUPRC:  0.6059787508166388 F1:  0.5676532769556026
# 0.7013443435925988 0.6474600466171374 0.6600735970561178 0.5843644544431946
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2954 - acc: 0.9197
# Epoch 1: val_loss improved from inf to 0.25950, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 22s 82ms/step - loss: 0.2954 - acc: 0.9197 - val_loss: 0.2595 - val_acc: 0.9247
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2547 - acc: 0.9217
# Epoch 2: val_loss did not improve from 0.25950
# 238/238 [==============================] - 19s 80ms/step - loss: 0.2547 - acc: 0.9217 - val_loss: 0.2799 - val_acc: 0.9247
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2411 - acc: 0.9218
# Epoch 3: val_loss did not improve from 0.25950
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2411 - acc: 0.9218 - val_loss: 0.2641 - val_acc: 0.9238
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2278 - acc: 0.9235
# Epoch 4: val_loss did not improve from 0.25950
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2278 - acc: 0.9235 - val_loss: 0.2609 - val_acc: 0.9219
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2072 - acc: 0.9272
# Epoch 5: val_loss did not improve from 0.25950
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2072 - acc: 0.9272 - val_loss: 0.2802 - val_acc: 0.9140
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1816 - acc: 0.9351
# Epoch 6: val_loss did not improve from 0.25950
# 238/238 [==============================] - 19s 79ms/step - loss: 0.1816 - acc: 0.9351 - val_loss: 0.2914 - val_acc: 0.9177
# AUC:  0.6821955005516651 AUPRC:  0.1952253069613234 F1:  0.13114754098360654
# 0.7178640989844858 0.19207057018645088 0.9178932842686293 0.0
# Iteration number:  3
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2854 - acc: 0.9028
# Epoch 1: val_loss improved from inf to 0.24723, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 23s 83ms/step - loss: 0.2854 - acc: 0.9028 - val_loss: 0.2472 - val_acc: 0.9104
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2399 - acc: 0.9132
# Epoch 2: val_loss did not improve from 0.24723
# 238/238 [==============================] - 18s 78ms/step - loss: 0.2399 - acc: 0.9132 - val_loss: 0.2586 - val_acc: 0.8974
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2211 - acc: 0.9194
# Epoch 3: val_loss improved from 0.24723 to 0.23464, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2211 - acc: 0.9194 - val_loss: 0.2346 - val_acc: 0.9159
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2027 - acc: 0.9267
# Epoch 4: val_loss did not improve from 0.23464
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2027 - acc: 0.9267 - val_loss: 0.2498 - val_acc: 0.9131
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1827 - acc: 0.9336
# Epoch 5: val_loss did not improve from 0.23464
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1827 - acc: 0.9336 - val_loss: 0.2465 - val_acc: 0.9108
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1560 - acc: 0.9411
# Epoch 6: val_loss did not improve from 0.23464
# 238/238 [==============================] - 18s 76ms/step - loss: 0.1560 - acc: 0.9411 - val_loss: 0.2641 - val_acc: 0.8956
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1222 - acc: 0.9549
# Epoch 7: val_loss did not improve from 0.23464
# 238/238 [==============================] - 18s 76ms/step - loss: 0.1222 - acc: 0.9549 - val_loss: 0.2755 - val_acc: 0.9071
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0874 - acc: 0.9678
# Epoch 8: val_loss did not improve from 0.23464
# 238/238 [==============================] - 18s 76ms/step - loss: 0.0874 - acc: 0.9678 - val_loss: 0.3528 - val_acc: 0.8993
# AUC:  0.842154044409199 AUPRC:  0.5173967758377122 F1:  0.47102342786683105
# 0.8828564190677592 0.5778311596756459 0.9114535418583257 0.4790257104194858
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2163 - acc: 0.9340
# Epoch 1: val_loss improved from inf to 0.18292, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 22s 79ms/step - loss: 0.2163 - acc: 0.9340 - val_loss: 0.1829 - val_acc: 0.9432
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1744 - acc: 0.9424
# Epoch 2: val_loss improved from 0.18292 to 0.17766, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 18s 78ms/step - loss: 0.1744 - acc: 0.9424 - val_loss: 0.1777 - val_acc: 0.9404
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1569 - acc: 0.9472
# Epoch 3: val_loss did not improve from 0.17766
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1569 - acc: 0.9472 - val_loss: 0.1785 - val_acc: 0.9409
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1408 - acc: 0.9485
# Epoch 4: val_loss improved from 0.17766 to 0.17495, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1408 - acc: 0.9485 - val_loss: 0.1749 - val_acc: 0.9362
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1234 - acc: 0.9543
# Epoch 5: val_loss did not improve from 0.17495
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1234 - acc: 0.9543 - val_loss: 0.1815 - val_acc: 0.9404
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0990 - acc: 0.9641
# Epoch 6: val_loss did not improve from 0.17495
# 238/238 [==============================] - 18s 75ms/step - loss: 0.0990 - acc: 0.9641 - val_loss: 0.2157 - val_acc: 0.9367
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0744 - acc: 0.9735
# Epoch 7: val_loss did not improve from 0.17495
# 238/238 [==============================] - 18s 77ms/step - loss: 0.0744 - acc: 0.9735 - val_loss: 0.2131 - val_acc: 0.9413
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0539 - acc: 0.9817
# Epoch 8: val_loss did not improve from 0.17495
# 238/238 [==============================] - 18s 78ms/step - loss: 0.0539 - acc: 0.9817 - val_loss: 0.2395 - val_acc: 0.9445
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0354 - acc: 0.9886
# Epoch 9: val_loss did not improve from 0.17495
# 238/238 [==============================] - 19s 79ms/step - loss: 0.0354 - acc: 0.9886 - val_loss: 0.2922 - val_acc: 0.9265
# AUC:  0.8506102033490957 AUPRC:  0.463252779367113 F1:  0.47574334898278564
# 0.8797005945971254 0.5020611799962402 0.9339926402943882 0.46950092421441775
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6662 - acc: 0.6314
# Epoch 1: val_loss improved from inf to 0.63010, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 22s 79ms/step - loss: 0.6662 - acc: 0.6314 - val_loss: 0.6301 - val_acc: 0.6687
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6271 - acc: 0.6644
# Epoch 2: val_loss improved from 0.63010 to 0.61476, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.6271 - acc: 0.6644 - val_loss: 0.6148 - val_acc: 0.6802
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6082 - acc: 0.6779
# Epoch 3: val_loss did not improve from 0.61476
# 238/238 [==============================] - 18s 77ms/step - loss: 0.6082 - acc: 0.6779 - val_loss: 0.6177 - val_acc: 0.6751
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5892 - acc: 0.6946
# Epoch 4: val_loss did not improve from 0.61476
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5892 - acc: 0.6946 - val_loss: 0.6163 - val_acc: 0.6604
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5645 - acc: 0.7147
# Epoch 5: val_loss did not improve from 0.61476
# 238/238 [==============================] - 18s 77ms/step - loss: 0.5645 - acc: 0.7147 - val_loss: 0.6267 - val_acc: 0.6520
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5270 - acc: 0.7446
# Epoch 6: val_loss did not improve from 0.61476
# 238/238 [==============================] - 18s 77ms/step - loss: 0.5270 - acc: 0.7446 - val_loss: 0.6569 - val_acc: 0.6511
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4805 - acc: 0.7750
# Epoch 7: val_loss did not improve from 0.61476
# 238/238 [==============================] - 19s 81ms/step - loss: 0.4805 - acc: 0.7750 - val_loss: 0.6815 - val_acc: 0.6428
# AUC:  0.6766587682838929 AUPRC:  0.6142841761266642 F1:  0.5798657718120805
# 0.7041265812950758 0.6471310401716268 0.6607635694572217 0.5321915635902316
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2962 - acc: 0.9167
# Epoch 1: val_loss improved from inf to 0.26097, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 22s 82ms/step - loss: 0.2962 - acc: 0.9167 - val_loss: 0.2610 - val_acc: 0.9242
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2545 - acc: 0.9223
# Epoch 2: val_loss improved from 0.26097 to 0.25779, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.2545 - acc: 0.9223 - val_loss: 0.2578 - val_acc: 0.9247
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2400 - acc: 0.9221
# Epoch 3: val_loss did not improve from 0.25779
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2400 - acc: 0.9221 - val_loss: 0.2581 - val_acc: 0.9251
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2252 - acc: 0.9225
# Epoch 4: val_loss did not improve from 0.25779
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2252 - acc: 0.9225 - val_loss: 0.2676 - val_acc: 0.9247
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2061 - acc: 0.9267
# Epoch 5: val_loss did not improve from 0.25779
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2061 - acc: 0.9267 - val_loss: 0.2868 - val_acc: 0.9214
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1772 - acc: 0.9369
# Epoch 6: val_loss did not improve from 0.25779
# 238/238 [==============================] - 18s 77ms/step - loss: 0.1772 - acc: 0.9369 - val_loss: 0.3010 - val_acc: 0.9210
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1433 - acc: 0.9466
# Epoch 7: val_loss did not improve from 0.25779
# 238/238 [==============================] - 18s 78ms/step - loss: 0.1433 - acc: 0.9466 - val_loss: 0.3240 - val_acc: 0.9071
# AUC:  0.6911667435995588 AUPRC:  0.16535152272057585 F1:  0.1417004048582996
# 0.7071097954335638 0.1921923415883654 0.9185832566697332 0.0111731843575419
# Iteration number:  4
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2820 - acc: 0.9040
# Epoch 1: val_loss improved from inf to 0.24489, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 23s 82ms/step - loss: 0.2820 - acc: 0.9040 - val_loss: 0.2449 - val_acc: 0.9131
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2387 - acc: 0.9139
# Epoch 2: val_loss improved from 0.24489 to 0.23726, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2387 - acc: 0.9139 - val_loss: 0.2373 - val_acc: 0.9122
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2179 - acc: 0.9200
# Epoch 3: val_loss improved from 0.23726 to 0.23452, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.2179 - acc: 0.9200 - val_loss: 0.2345 - val_acc: 0.9168
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2013 - acc: 0.9262
# Epoch 4: val_loss did not improve from 0.23452
# 238/238 [==============================] - 19s 78ms/step - loss: 0.2013 - acc: 0.9262 - val_loss: 0.2479 - val_acc: 0.9053
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1778 - acc: 0.9344
# Epoch 5: val_loss did not improve from 0.23452
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1778 - acc: 0.9344 - val_loss: 0.2828 - val_acc: 0.9168
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1441 - acc: 0.9451
# Epoch 6: val_loss did not improve from 0.23452
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1441 - acc: 0.9451 - val_loss: 0.3137 - val_acc: 0.8683
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1101 - acc: 0.9596
# Epoch 7: val_loss did not improve from 0.23452
# 238/238 [==============================] - 18s 78ms/step - loss: 0.1101 - acc: 0.9596 - val_loss: 0.3053 - val_acc: 0.8965
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0819 - acc: 0.9700
# Epoch 8: val_loss did not improve from 0.23452
# 238/238 [==============================] - 18s 77ms/step - loss: 0.0819 - acc: 0.9700 - val_loss: 0.3783 - val_acc: 0.8942
# AUC:  0.8317728984932594 AUPRC:  0.508487507627951 F1:  0.4644194756554306
# 0.8795653802097102 0.5878775526343487 0.9165133394664213 0.449165402124431
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2134 - acc: 0.9323
# Epoch 1: val_loss improved from inf to 0.17994, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 22s 82ms/step - loss: 0.2134 - acc: 0.9323 - val_loss: 0.1799 - val_acc: 0.9422
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1724 - acc: 0.9421
# Epoch 2: val_loss improved from 0.17994 to 0.17642, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 19s 79ms/step - loss: 0.1724 - acc: 0.9421 - val_loss: 0.1764 - val_acc: 0.9445
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1552 - acc: 0.9451
# Epoch 3: val_loss did not improve from 0.17642
# 238/238 [==============================] - 18s 76ms/step - loss: 0.1552 - acc: 0.9451 - val_loss: 0.1784 - val_acc: 0.9395
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1377 - acc: 0.9512
# Epoch 4: val_loss improved from 0.17642 to 0.17392, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1377 - acc: 0.9512 - val_loss: 0.1739 - val_acc: 0.9381
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1159 - acc: 0.9579
# Epoch 5: val_loss did not improve from 0.17392
# 238/238 [==============================] - 19s 78ms/step - loss: 0.1159 - acc: 0.9579 - val_loss: 0.2115 - val_acc: 0.9399
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0936 - acc: 0.9660
# Epoch 6: val_loss did not improve from 0.17392
# 238/238 [==============================] - 19s 78ms/step - loss: 0.0936 - acc: 0.9660 - val_loss: 0.2626 - val_acc: 0.9422
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0669 - acc: 0.9763
# Epoch 7: val_loss did not improve from 0.17392
# 238/238 [==============================] - 19s 79ms/step - loss: 0.0669 - acc: 0.9763 - val_loss: 0.2502 - val_acc: 0.9302
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0464 - acc: 0.9841
# Epoch 8: val_loss did not improve from 0.17392
# 238/238 [==============================] - 19s 78ms/step - loss: 0.0464 - acc: 0.9841 - val_loss: 0.2819 - val_acc: 0.9348
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0332 - acc: 0.9886
# Epoch 9: val_loss did not improve from 0.17392
# 238/238 [==============================] - 19s 79ms/step - loss: 0.0332 - acc: 0.9886 - val_loss: 0.3471 - val_acc: 0.9372
# AUC:  0.8327203988950793 AUPRC:  0.4353260723256199 F1:  0.40899795501022496
# 0.8782905722802253 0.5109814057905371 0.9383624655013799 0.4552845528455284
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6634 - acc: 0.6282
# Epoch 1: val_loss improved from inf to 0.62399, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 22s 81ms/step - loss: 0.6634 - acc: 0.6282 - val_loss: 0.6240 - val_acc: 0.6631
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6225 - acc: 0.6668
# Epoch 2: val_loss improved from 0.62399 to 0.61672, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 79ms/step - loss: 0.6225 - acc: 0.6668 - val_loss: 0.6167 - val_acc: 0.6677
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6042 - acc: 0.6812
# Epoch 3: val_loss improved from 0.61672 to 0.61494, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.6042 - acc: 0.6812 - val_loss: 0.6149 - val_acc: 0.6742
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5835 - acc: 0.6970
# Epoch 4: val_loss did not improve from 0.61494
# 238/238 [==============================] - 18s 77ms/step - loss: 0.5835 - acc: 0.6970 - val_loss: 0.6266 - val_acc: 0.6640
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5569 - acc: 0.7188
# Epoch 5: val_loss did not improve from 0.61494
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5569 - acc: 0.7188 - val_loss: 0.6281 - val_acc: 0.6668
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5142 - acc: 0.7483
# Epoch 6: val_loss did not improve from 0.61494
# 238/238 [==============================] - 18s 78ms/step - loss: 0.5142 - acc: 0.7483 - val_loss: 0.6572 - val_acc: 0.6548
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4602 - acc: 0.7853
# Epoch 7: val_loss did not improve from 0.61494
# 238/238 [==============================] - 19s 78ms/step - loss: 0.4602 - acc: 0.7853 - val_loss: 0.6860 - val_acc: 0.6317
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.3847 - acc: 0.8301
# Epoch 8: val_loss did not improve from 0.61494
# 238/238 [==============================] - 18s 76ms/step - loss: 0.3847 - acc: 0.8301 - val_loss: 0.7857 - val_acc: 0.6386
# AUC:  0.6734877618227568 AUPRC:  0.6177156683794129 F1:  0.5749530705282918
# 0.7026548061443376 0.6474345235922173 0.6589236430542779 0.5142482803799542
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2868 - acc: 0.9186
# Epoch 1: val_loss improved from inf to 0.26598, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 22s 79ms/step - loss: 0.2868 - acc: 0.9186 - val_loss: 0.2660 - val_acc: 0.9247
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2542 - acc: 0.9213
# Epoch 2: val_loss improved from 0.26598 to 0.26060, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 18s 76ms/step - loss: 0.2542 - acc: 0.9213 - val_loss: 0.2606 - val_acc: 0.9251
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2397 - acc: 0.9225
# Epoch 3: val_loss improved from 0.26060 to 0.25586, saving model to 64-basiccnn1d-word2vec-los_7-best_model.hdf5
# 238/238 [==============================] - 16s 67ms/step - loss: 0.2397 - acc: 0.9225 - val_loss: 0.2559 - val_acc: 0.9251
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2224 - acc: 0.9233
# Epoch 4: val_loss did not improve from 0.25586
# 238/238 [==============================] - 16s 68ms/step - loss: 0.2224 - acc: 0.9233 - val_loss: 0.2631 - val_acc: 0.9219
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2010 - acc: 0.9298
# Epoch 5: val_loss did not improve from 0.25586
# 238/238 [==============================] - 15s 65ms/step - loss: 0.2010 - acc: 0.9298 - val_loss: 0.2785 - val_acc: 0.9196
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1793 - acc: 0.9357
# Epoch 6: val_loss did not improve from 0.25586
# 238/238 [==============================] - 16s 66ms/step - loss: 0.1793 - acc: 0.9357 - val_loss: 0.2869 - val_acc: 0.9104
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1397 - acc: 0.9481
# Epoch 7: val_loss did not improve from 0.25586
# 238/238 [==============================] - 16s 67ms/step - loss: 0.1397 - acc: 0.9481 - val_loss: 0.3248 - val_acc: 0.9117
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1109 - acc: 0.9601
# Epoch 8: val_loss did not improve from 0.25586
# 238/238 [==============================] - 16s 66ms/step - loss: 0.1109 - acc: 0.9601 - val_loss: 0.3375 - val_acc: 0.9080
# AUC:  0.6846663833284548 AUPRC:  0.18781834974999007 F1:  0.1593625498007968
# 0.7372174123527954 0.22509979485453227 0.9169733210671573 0.047493403693931395
# Iteration number:  5
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2826 - acc: 0.9031
# Epoch 1: val_loss improved from inf to 0.25938, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 20s 73ms/step - loss: 0.2826 - acc: 0.9031 - val_loss: 0.2594 - val_acc: 0.9080
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2372 - acc: 0.9144
# Epoch 2: val_loss improved from 0.25938 to 0.23916, saving model to 64-basiccnn1d-word2vec-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 16s 68ms/step - loss: 0.2372 - acc: 0.9144 - val_loss: 0.2392 - val_acc: 0.9122
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2193 - acc: 0.9194
# Epoch 3: val_loss did not improve from 0.23916
# 238/238 [==============================] - 17s 70ms/step - loss: 0.2193 - acc: 0.9194 - val_loss: 0.2412 - val_acc: 0.9145
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1993 - acc: 0.9253
# Epoch 4: val_loss did not improve from 0.23916
# 238/238 [==============================] - 16s 66ms/step - loss: 0.1993 - acc: 0.9253 - val_loss: 0.2510 - val_acc: 0.8983
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1781 - acc: 0.9334
# Epoch 5: val_loss did not improve from 0.23916
# 238/238 [==============================] - 16s 69ms/step - loss: 0.1781 - acc: 0.9334 - val_loss: 0.2694 - val_acc: 0.9136
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1501 - acc: 0.9428
# Epoch 6: val_loss did not improve from 0.23916
# 238/238 [==============================] - 16s 68ms/step - loss: 0.1501 - acc: 0.9428 - val_loss: 0.2802 - val_acc: 0.8974
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1153 - acc: 0.9565
# Epoch 7: val_loss did not improve from 0.23916
# 238/238 [==============================] - 16s 68ms/step - loss: 0.1153 - acc: 0.9565 - val_loss: 0.3143 - val_acc: 0.9048
# AUC:  0.8484819697770728 AUPRC:  0.5199060281436265 F1:  0.42105263157894735
# 0.8591880341880342 0.5280812973601905 0.9098436062557498 0.3855799373040752
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2149 - acc: 0.9335
# Epoch 1: val_loss improved from inf to 0.17283, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 19s 69ms/step - loss: 0.2149 - acc: 0.9335 - val_loss: 0.1728 - val_acc: 0.9436
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1743 - acc: 0.9424
# Epoch 2: val_loss improved from 0.17283 to 0.17161, saving model to 64-basiccnn1d-word2vec-mort_icu-best_model.hdf5
# 238/238 [==============================] - 16s 67ms/step - loss: 0.1743 - acc: 0.9424 - val_loss: 0.1716 - val_acc: 0.9418
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1578 - acc: 0.9446
# Epoch 3: val_loss did not improve from 0.17161
# 238/238 [==============================] - 16s 69ms/step - loss: 0.1578 - acc: 0.9446 - val_loss: 0.1788 - val_acc: 0.9413
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1400 - acc: 0.9514
# Epoch 4: val_loss did not improve from 0.17161
# 238/238 [==============================] - 16s 67ms/step - loss: 0.1400 - acc: 0.9514 - val_loss: 0.1894 - val_acc: 0.9459
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1205 - acc: 0.9556
# Epoch 5: val_loss did not improve from 0.17161
# 238/238 [==============================] - 16s 68ms/step - loss: 0.1205 - acc: 0.9556 - val_loss: 0.1773 - val_acc: 0.9381
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0958 - acc: 0.9645
# Epoch 6: val_loss did not improve from 0.17161
# 238/238 [==============================] - 16s 67ms/step - loss: 0.0958 - acc: 0.9645 - val_loss: 0.1938 - val_acc: 0.9385
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0684 - acc: 0.9761
# Epoch 7: val_loss did not improve from 0.17161
# 238/238 [==============================] - 16s 68ms/step - loss: 0.0684 - acc: 0.9761 - val_loss: 0.2409 - val_acc: 0.9395
# AUC:  0.8475123679323314 AUPRC:  0.4681946009633289 F1:  0.4173913043478261
# 0.8782987655477004 0.5122792076622823 0.9420423183072677 0.4166666666666667
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6707 - acc: 0.6264
# Epoch 1: val_loss improved from inf to 0.61941, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 70ms/step - loss: 0.6707 - acc: 0.6264 - val_loss: 0.6194 - val_acc: 0.6816
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6234 - acc: 0.6673
# Epoch 2: val_loss improved from 0.61941 to 0.61480, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 17s 70ms/step - loss: 0.6234 - acc: 0.6673 - val_loss: 0.6148 - val_acc: 0.6640
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6054 - acc: 0.6849
# Epoch 3: val_loss improved from 0.61480 to 0.61287, saving model to 64-basiccnn1d-word2vec-los_3-best_model.hdf5
# 238/238 [==============================] - 17s 70ms/step - loss: 0.6054 - acc: 0.6849 - val_loss: 0.6129 - val_acc: 0.6761
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5885 - acc: 0.6966
# Epoch 4: val_loss did not improve from 0.61287
# 238/238 [==============================] - 16s 69ms/step - loss: 0.5885 - acc: 0.6966 - val_loss: 0.6156 - val_acc: 0.6710
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5617 - acc: 0.7153
# Epoch 5: val_loss did not improve from 0.61287
# 238/238 [==============================] - 17s 71ms/step - loss: 0.5617 - acc: 0.7153 - val_loss: 0.6310 - val_acc: 0.6733
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5310 - acc: 0.7377
# Epoch 6: val_loss did not improve from 0.61287
# 238/238 [==============================] - 16s 67ms/step - loss: 0.5310 - acc: 0.7377 - val_loss: 0.6380 - val_acc: 0.6673
# Epoch 7/100
# ...
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0571 - acc: 0.9807
# Epoch 8: val_loss did not improve from 0.17276
# 238/238 [==============================] - 19s 78ms/step - loss: 0.0571 - acc: 0.9807 - val_loss: 0.2741 - val_acc: 0.9298
# AUC:  0.8390046350484575 AUPRC:  0.4447736879388813 F1:  0.4335154826958105
# 0.8875946127315574 0.5133726863705158 0.937902483900644 0.45783132530120485
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6800 - acc: 0.6196
# Epoch 1: val_loss improved from inf to 0.62576, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 238/238 [==============================] - 22s 79ms/step - loss: 0.6800 - acc: 0.6196 - val_loss: 0.6258 - val_acc: 0.6738
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6267 - acc: 0.6621
# Epoch 2: val_loss improved from 0.62576 to 0.61968, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 238/238 [==============================] - 18s 77ms/step - loss: 0.6267 - acc: 0.6621 - val_loss: 0.6197 - val_acc: 0.6765
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6075 - acc: 0.6815
# Epoch 3: val_loss improved from 0.61968 to 0.61916, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 79ms/step - loss: 0.6075 - acc: 0.6815 - val_loss: 0.6192 - val_acc: 0.6617
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5893 - acc: 0.6962
# Epoch 4: val_loss improved from 0.61916 to 0.61775, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5893 - acc: 0.6962 - val_loss: 0.6178 - val_acc: 0.6719
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5613 - acc: 0.7189
# Epoch 5: val_loss did not improve from 0.61775
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5613 - acc: 0.7189 - val_loss: 0.6286 - val_acc: 0.6677
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5269 - acc: 0.7481
# Epoch 6: val_loss did not improve from 0.61775
# 238/238 [==============================] - 19s 78ms/step - loss: 0.5269 - acc: 0.7481 - val_loss: 0.6689 - val_acc: 0.6516
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4776 - acc: 0.7781
# Epoch 7: val_loss did not improve from 0.61775
# 238/238 [==============================] - 18s 76ms/step - loss: 0.4776 - acc: 0.7781 - val_loss: 0.6850 - val_acc: 0.6580
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4143 - acc: 0.8127
# Epoch 8: val_loss did not improve from 0.61775
# 238/238 [==============================] - 18s 75ms/step - loss: 0.4143 - acc: 0.8127 - val_loss: 0.7428 - val_acc: 0.6470
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.3515 - acc: 0.8518
# Epoch 9: val_loss did not improve from 0.61775
# 238/238 [==============================] - 18s 76ms/step - loss: 0.3515 - acc: 0.8518 - val_loss: 0.8810 - val_acc: 0.6363
# AUC:  0.6530951517741149 AUPRC:  0.602696754085287 F1:  0.5153892576946288
# 0.7008513420776632 0.6472356780437508 0.6573137074517019 0.5728211009174312
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.3046 - acc: 0.9164
# Epoch 1: val_loss improved from inf to 0.27045, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 238/238 [==============================] - 23s 84ms/step - loss: 0.3046 - acc: 0.9164 - val_loss: 0.2705 - val_acc: 0.9247
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2568 - acc: 0.9221
# Epoch 2: val_loss improved from 0.27045 to 0.26127, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 238/238 [==============================] - 19s 81ms/step - loss: 0.2568 - acc: 0.9221 - val_loss: 0.2613 - val_acc: 0.9233
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2411 - acc: 0.9217
# Epoch 3: val_loss improved from 0.26127 to 0.25713, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 238/238 [==============================] - 20s 83ms/step - loss: 0.2411 - acc: 0.9217 - val_loss: 0.2571 - val_acc: 0.9238
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2262 - acc: 0.9240
# Epoch 4: val_loss improved from 0.25713 to 0.25657, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 238/238 [==============================] - 19s 81ms/step - loss: 0.2262 - acc: 0.9240 - val_loss: 0.2566 - val_acc: 0.9251
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2054 - acc: 0.9278
# Epoch 5: val_loss did not improve from 0.25657
# 238/238 [==============================] - 19s 80ms/step - loss: 0.2054 - acc: 0.9278 - val_loss: 0.2827 - val_acc: 0.9238
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1789 - acc: 0.9349
# Epoch 6: val_loss did not improve from 0.25657
# 238/238 [==============================] - 19s 79ms/step - loss: 0.1789 - acc: 0.9349 - val_loss: 0.3096 - val_acc: 0.9159
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1450 - acc: 0.9475
# Epoch 7: val_loss did not improve from 0.25657
# 238/238 [==============================] - 19s 80ms/step - loss: 0.1450 - acc: 0.9475 - val_loss: 0.3442 - val_acc: 0.8997
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1103 - acc: 0.9593
# Epoch 8: val_loss did not improve from 0.25657
# 238/238 [==============================] - 19s 79ms/step - loss: 0.1103 - acc: 0.9593 - val_loss: 0.4117 - val_acc: 0.9076
# Epoch 9/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0719 - acc: 0.9771
# Epoch 9: val_loss did not improve from 0.25657
# 238/238 [==============================] - 19s 80ms/step - loss: 0.0719 - acc: 0.9771 - val_loss: 0.4317 - val_acc: 0.8909
# AUC:  0.6300751080813313 AUPRC:  0.15343585641941032 F1:  0.15302491103202848
# 0.7093646562788498 0.1969458800034893 0.9174333026678932 0.04774535809018567
# Iteration number:  10
# Problem type:  mort_hosp
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2933 - acc: 0.9013
# Epoch 1: val_loss improved from inf to 0.25310, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 23s 84ms/step - loss: 0.2933 - acc: 0.9013 - val_loss: 0.2531 - val_acc: 0.9136
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2411 - acc: 0.9145
# Epoch 2: val_loss improved from 0.25310 to 0.23965, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 19s 81ms/step - loss: 0.2411 - acc: 0.9145 - val_loss: 0.2396 - val_acc: 0.9173
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2232 - acc: 0.9192
# Epoch 3: val_loss improved from 0.23965 to 0.23119, saving model to 64-basiccnn1d-concat-mort_hosp-best_model.hdf5
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2232 - acc: 0.9192 - val_loss: 0.2312 - val_acc: 0.9150
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2032 - acc: 0.9238
# Epoch 4: val_loss did not improve from 0.23119
# 238/238 [==============================] - 19s 80ms/step - loss: 0.2032 - acc: 0.9238 - val_loss: 0.2468 - val_acc: 0.9020
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1828 - acc: 0.9309
# Epoch 5: val_loss did not improve from 0.23119
# 238/238 [==============================] - 19s 81ms/step - loss: 0.1828 - acc: 0.9309 - val_loss: 0.2464 - val_acc: 0.9113
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1572 - acc: 0.9421
# Epoch 6: val_loss did not improve from 0.23119
# 238/238 [==============================] - 19s 79ms/step - loss: 0.1572 - acc: 0.9421 - val_loss: 0.2711 - val_acc: 0.9122
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1263 - acc: 0.9531
# Epoch 7: val_loss did not improve from 0.23119
# 238/238 [==============================] - 19s 80ms/step - loss: 0.1263 - acc: 0.9531 - val_loss: 0.3134 - val_acc: 0.9071
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0948 - acc: 0.9668
# Epoch 8: val_loss did not improve from 0.23119
# 238/238 [==============================] - 19s 81ms/step - loss: 0.0948 - acc: 0.9668 - val_loss: 0.3564 - val_acc: 0.8933
# AUC:  0.839202242488325 AUPRC:  0.5250273610866178 F1:  0.4865470852017938
# 0.8726914265574061 0.566791754325575 0.9151333946642134 0.4366412213740458
# Problem type:  mort_icu
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2249 - acc: 0.9316
# Epoch 1: val_loss improved from inf to 0.18176, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# 238/238 [==============================] - 23s 85ms/step - loss: 0.2249 - acc: 0.9316 - val_loss: 0.1818 - val_acc: 0.9409
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1758 - acc: 0.9425
# Epoch 2: val_loss improved from 0.18176 to 0.17415, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# 238/238 [==============================] - 20s 83ms/step - loss: 0.1758 - acc: 0.9425 - val_loss: 0.1742 - val_acc: 0.9427
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1599 - acc: 0.9448
# Epoch 3: val_loss improved from 0.17415 to 0.16677, saving model to 64-basiccnn1d-concat-mort_icu-best_model.hdf5
# 238/238 [==============================] - 19s 81ms/step - loss: 0.1599 - acc: 0.9448 - val_loss: 0.1668 - val_acc: 0.9413
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1425 - acc: 0.9497
# Epoch 4: val_loss did not improve from 0.16677
# 238/238 [==============================] - 20s 82ms/step - loss: 0.1425 - acc: 0.9497 - val_loss: 0.1744 - val_acc: 0.9432
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1239 - acc: 0.9557
# Epoch 5: val_loss did not improve from 0.16677
# 238/238 [==============================] - 20s 83ms/step - loss: 0.1239 - acc: 0.9557 - val_loss: 0.1908 - val_acc: 0.9367
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1033 - acc: 0.9606
# Epoch 6: val_loss did not improve from 0.16677
# 238/238 [==============================] - 19s 79ms/step - loss: 0.1033 - acc: 0.9606 - val_loss: 0.2046 - val_acc: 0.9413
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0809 - acc: 0.9703
# Epoch 7: val_loss did not improve from 0.16677
# 238/238 [==============================] - 19s 79ms/step - loss: 0.0809 - acc: 0.9703 - val_loss: 0.2067 - val_acc: 0.9288
# Epoch 8/100
# 238/238 [==============================] - ETA: 0s - loss: 0.0594 - acc: 0.9787
# Epoch 8: val_loss did not improve from 0.16677
# 238/238 [==============================] - 19s 81ms/step - loss: 0.0594 - acc: 0.9787 - val_loss: 0.2286 - val_acc: 0.9321
# AUC:  0.8432233874869298 AUPRC:  0.4526463746535509 F1:  0.4482173174872666
# 0.8827718994334941 0.5205487367856008 0.9408923643054278 0.4009324009324009
# Problem type:  los_3
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6816 - acc: 0.6248
# Epoch 1: val_loss improved from inf to 0.63696, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 238/238 [==============================] - 23s 85ms/step - loss: 0.6816 - acc: 0.6248 - val_loss: 0.6370 - val_acc: 0.6682
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6302 - acc: 0.6652
# Epoch 2: val_loss improved from 0.63696 to 0.62048, saving model to 64-basiccnn1d-concat-los_3-best_model.hdf5
# 238/238 [==============================] - 19s 82ms/step - loss: 0.6302 - acc: 0.6652 - val_loss: 0.6205 - val_acc: 0.6668
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.6122 - acc: 0.6793
# Epoch 3: val_loss did not improve from 0.62048
# 238/238 [==============================] - 19s 81ms/step - loss: 0.6122 - acc: 0.6793 - val_loss: 0.6251 - val_acc: 0.6613
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5923 - acc: 0.6951
# Epoch 4: val_loss did not improve from 0.62048
# 238/238 [==============================] - 19s 79ms/step - loss: 0.5923 - acc: 0.6951 - val_loss: 0.6325 - val_acc: 0.6664
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5693 - acc: 0.7106
# Epoch 5: val_loss did not improve from 0.62048
# 238/238 [==============================] - 19s 81ms/step - loss: 0.5693 - acc: 0.7106 - val_loss: 0.6277 - val_acc: 0.6557
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.5400 - acc: 0.7307
# Epoch 6: val_loss did not improve from 0.62048
# 238/238 [==============================] - 19s 80ms/step - loss: 0.5400 - acc: 0.7307 - val_loss: 0.6419 - val_acc: 0.6608
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.4929 - acc: 0.7638
# Epoch 7: val_loss did not improve from 0.62048
# 238/238 [==============================] - 19s 80ms/step - loss: 0.4929 - acc: 0.7638 - val_loss: 0.6810 - val_acc: 0.6543
# AUC:  0.6517890052785367 AUPRC:  0.607130955004409 F1:  0.5392938496583144
# 0.6939734907830621 0.6381390303032238 0.6550137994480221 0.554367201426025
# Problem type:  los_7
# __________________
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Epoch 1/100
# 238/238 [==============================] - ETA: 0s - loss: 0.3026 - acc: 0.9175
# Epoch 1: val_loss improved from inf to 0.27034, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 238/238 [==============================] - 22s 83ms/step - loss: 0.3026 - acc: 0.9175 - val_loss: 0.2703 - val_acc: 0.9238
# Epoch 2/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2538 - acc: 0.9220
# Epoch 2: val_loss improved from 0.27034 to 0.26089, saving model to 64-basiccnn1d-concat-los_7-best_model.hdf5
# 238/238 [==============================] - 19s 80ms/step - loss: 0.2538 - acc: 0.9220 - val_loss: 0.2609 - val_acc: 0.9247
# Epoch 3/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2409 - acc: 0.9223
# Epoch 3: val_loss did not improve from 0.26089
# 238/238 [==============================] - 19s 80ms/step - loss: 0.2409 - acc: 0.9223 - val_loss: 0.2654 - val_acc: 0.9247
# Epoch 4/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2242 - acc: 0.9242
# Epoch 4: val_loss did not improve from 0.26089
# 238/238 [==============================] - 18s 78ms/step - loss: 0.2242 - acc: 0.9242 - val_loss: 0.2685 - val_acc: 0.9196
# Epoch 5/100
# 238/238 [==============================] - ETA: 0s - loss: 0.2009 - acc: 0.9284
# Epoch 5: val_loss did not improve from 0.26089
# 238/238 [==============================] - 19s 79ms/step - loss: 0.2009 - acc: 0.9284 - val_loss: 0.2656 - val_acc: 0.9191
# Epoch 6/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1772 - acc: 0.9354
# Epoch 6: val_loss did not improve from 0.26089
# 238/238 [==============================] - 19s 81ms/step - loss: 0.1772 - acc: 0.9354 - val_loss: 0.2877 - val_acc: 0.9076
# Epoch 7/100
# 238/238 [==============================] - ETA: 0s - loss: 0.1456 - acc: 0.9477
# Epoch 7: val_loss did not improve from 0.26089
# 238/238 [==============================] - 20s 85ms/step - loss: 0.1456 - acc: 0.9477 - val_loss: 0.3161 - val_acc: 0.8900
# AUC:  0.6645309579833826 AUPRC:  0.16162510885200795 F1:  0.17901234567901236
# 0.7294589178356713 0.2062121452250467 0.9183532658693653 0.005602240896358543
